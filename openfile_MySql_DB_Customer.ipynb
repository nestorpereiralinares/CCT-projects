# %% [markdown]
# <a href="https://colab.research.google.com/github/nestorpereiralinares/Machine-Learning-Projects/blob/master/openfile_MySql_DB_Customer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# open file DB MySql 

# Install MySQL Connector Python using pip:    python -m pip install mysql-connector-python

# //user:password@host/dbname[?key=value..], 

# tips: use shif-tab to see the parameters of the command

# SQLAlchemy library

# MySql:   using Python native
    
#import mysql.connector    
   
# 3- Query 3 on Python SQLAlchemy and connecting to database
# using sqlalchemy

# pip install sqlalchemy

import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine


# mysql - MySQLdb (mysql-python) is the default driver
#mysql_db = create_engine('mysql://scott:tiger@localhost/foo')
#mysql_db = create_engine('mysql+mysqldb://scott:tiger@localhost/foo')



 # Create the db engine

engine = create_engine('mysql+mysqldb://root:Marylu1104@localhost/classicmodels')
engine.connect() # connect to the database
print(engine)
# Out:
# Engine(mysql+mysqldb://root:***@localhost/classicmodels)

# %%
# Query 1 on the relational table
sql_query = 'Select * from customers;'
records = engine.execute(sql_query)

for row in records:
    print(row)
# Out:
# (103, 'Atelier graphique', 'Schmitt', 'Carine ', '40.32.2555', '54, rue Royale', None, 'Nantes', None, '44000', 'France', 1370, Decimal('21000.00'))
# (112, 'Signal Gift Stores', 'King', 'Jean', '7025551838', '8489 Strong St.', None, 'Las Vegas', 'NV', '83030', 'USA', 1166, Decimal('71800.00'))
# (114, 'Australian Collectors, Co.', 'Ferguson', 'Peter', '03 9520 4555', '636 St Kilda Road', 'Level 3', 'Melbourne', 'Victoria', '3004', 'Australia', 1611, Decimal('117300.00'))
# (119, 'La Rochelle Gifts', 'Labrune', 'Janine ', '40.67.8555', '67, rue des Cinquante Otages', None, 'Nantes', None, '44000', 'France', 1370, Decimal('118200.00'))
# (121, 'Baane Mini Imports', 'Bergulfsen', 'Jonas ', '07-98 9555', 'Erling Skakkes gate 78', None, 'Stavern', None, '4110', 'Norway', 1504, Decimal('81700.00'))
# (124, 'Mini Gifts Distributors Ltd.', 'Nelson', 'Susan', '4155551450', '5677 Strong St.', None, 'San Rafael', 'CA', '97562', 'USA', 1165, Decimal('210500.00'))
# ...

# %%
table_names = engine.table_names()

print(table_names)
# Out:
# ['customers', 'employees', 'offices', 'orderdetails', 'orders', 'payments', 'productlines', 'products']

# %%
# Query 1 on table customers and store in DF (using fetchall())
import pandas as pd

con = engine.connect() 
sql_query1 = 'Select * from customers;'
rs = engine.execute(sql_query1)
df_customers = pd.DataFrame(rs.fetchall())
df_customers.columns = rs.keys()
con.close()


print(df_customers)
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %%
print(df_customers['customerNumber'])
print(df_customers.customerNumber) # not use for notation reason
print(type(df_customers['customerNumber']))
# Out:
# 0      103
# 1      112
# 2      114
# 3      119
# 4      121
#       ...
# 117    486
# 118    487
# 119    489
# 120    495
# 121    496
# Name: customerNumber, Length: 122, dtype: int64
# 0      103
# 1      112
# 2      114
# 3      119
# 4      121
#       ...
# 117    486
# 118    487
# 119    489
# 120    495
# 121    496
# Name: customerNumber, Length: 122, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
df_customers['new'] = df_customers['city']+df_customers['country'] #add new column

# %%
df_customers.drop('new',axis=1,inplace=True) 
# drop column use axis=1, axis=0 is row
#IMPORTANT:  inplace=True real delete the column from df

# %%
# --------------
# create df from query using engine and pandas
# --------------

sql_query1 = 'Select * from customers;'
df_customers = pd.read_sql_query(sql_query1,engine)

# %%
df_customers
# --------
# Important: create a copy of the original table (df)
# --------

df_customers_v0 = df_customers.copy(deep=True)  # any change in the copy NOT MOODIFY the original

# .copy(deep=True)  NOT modify original

# %%
# create df from query using engine and pandas

sql_query2 = 'select * from orders;'
sql_query3 = 'select * from orderdetails;'
sql_query4 = 'select * from products;'

df_orders = pd.read_sql_query(sql_query2,engine)
df_orderdetails = pd.read_sql_query(sql_query3,engine)
df_products = pd.read_sql_query(sql_query4,engine)

# %%
type(df_customers)
type(df_orders)
df_orders.index
df_orders.shape
df_orders.describe
# Out:
# <bound method NDFrame.describe of      orderNumber   orderDate requiredDate shippedDate      status  \
# 0          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 2          10102  2003-01-10   2003-01-18  2003-01-14     Shipped
# 3          10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 4          10104  2003-01-31   2003-02-09  2003-02-01     Shipped
# ..           ...         ...          ...         ...         ...
# 321        10421  2005-05-29   2005-06-06        None  In Process
# 322        10422  2005-05-30   2005-06-11        None  In Process
# 323        10423  2005-05-30   2005-06-05        None  In Process
# 324        10424  2005-05-31   2005-06-08        None  In Process
# 325        10425  2005-05-31   2005-06-07        None  In Process
#
#                                               comments  customerNumber
# ...

# %%
type(df_customers['customerNumber'])
# Out:
# pandas.core.series.Series

# %%
print(df_customers.shape)
print(df_orders.shape)
# Out:
# (122, 13)
# (326, 7)

# %%
#delete row 0 from df  axis=0
df_customers.drop(0,axis=0) # for permanent delete include inplace=True #
# Out:
#      customerNumber                    customerName contactLastName  \
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# 5               124    Mini Gifts Distributors Ltd.          Nelson
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 1               Jean      7025551838               8489 Strong St.
# ...

# %%
df_customers.drop('new',axis=1,inplace=True) 
# drop column use axis=1, axis=0 is row
#IMPORTANT:  inplace=True real delete the column from df

# %%
df_orders[['orderNumber','orderDate','status']] # several columns
# Out:
#      orderNumber   orderDate      status
# 0          10100  2003-01-06     Shipped
# 1          10101  2003-01-09     Shipped
# 2          10102  2003-01-10     Shipped
# 3          10103  2003-01-29     Shipped
# 4          10104  2003-01-31     Shipped
# ..           ...         ...         ...
# 321        10421  2005-05-29  In Process
# 322        10422  2005-05-30  In Process
# 323        10423  2005-05-30  In Process
# 324        10424  2005-05-31  In Process
# 325        10425  2005-05-31  In Process
#
# [326 rows x 3 columns]

# %%
# select row in df

print(df_customers.loc[0])  # row 0, LOCation row on index
print(df_customers.iloc[0]) #row 0, use index location 0,1,2,3,4
# Out:
# customerNumber                          103
# customerName              Atelier graphique
# contactLastName                     Schmitt
# contactFirstName                    Carine
# phone                            40.32.2555
# addressLine1                 54, rue Royale
# addressLine2                           None
# city                                 Nantes
# state                                  None
# postalCode                            44000
# country                              France
# salesRepEmployeeNumber                 1370
# creditLimit                           21000
# Name: 0, dtype: object
# customerNumber                          103
# customerName              Atelier graphique
# contactLastName                     Schmitt
# contactFirstName                    Carine
# phone                            40.32.2555
# addressLine1                 54, rue Royale
# addressLine2                           None
# city                                 Nantes
# ...

# %%
# select row and columns # loc use index not position 0,1,2,3,4...
df_orders.loc[[0,10] ,['orderNumber','orderDate','status']] # 0,10 row, several columns
df_orders.loc[0:10,['orderNumber','orderDate','status']] # 0-10 row, several columns
df_orders.loc[0:,['orderNumber','orderDate','status']] # all row, several columns
df_orders.loc[0:5,'orderNumber':'status'] # all row, several columns
df_orders[['orderNumber','orderDate','status']]
# Out:
#      orderNumber   orderDate      status
# 0          10100  2003-01-06     Shipped
# 1          10101  2003-01-09     Shipped
# 2          10102  2003-01-10     Shipped
# 3          10103  2003-01-29     Shipped
# 4          10104  2003-01-31     Shipped
# ..           ...         ...         ...
# 321        10421  2005-05-29  In Process
# 322        10422  2005-05-30  In Process
# 323        10423  2005-05-30  In Process
# 324        10424  2005-05-31  In Process
# 325        10425  2005-05-31  In Process
#
# [326 rows x 3 columns]

# %%
# choose row with some conditions

df_orderdetails['quantityOrdered'] < 20
df_orderdetails[df_orderdetails['quantityOrdered'] < 20]

df_orderdetails.index
df_orderdetails.loc[2]
df_orderdetails[df_orderdetails['quantityOrdered'] < 20][['orderNumber','productCode']]
# use &  and | or
df_orderdetails[(df_orderdetails['quantityOrdered'] < 20) & (df_orderdetails['priceEach']>100)][['orderNumber','productCode']]
df_orderdetails[(df_orderdetails['quantityOrdered'] < 20) & (df_orderdetails['priceEach']>100)]
df_orderdetails[(df_orderdetails['quantityOrdered'] < 20) | (df_orderdetails['priceEach']>100)]
# Out:
#       orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 0           10100    S18_1749               30     136.00                3
# 4           10101    S18_2325               25     108.06                4
# 5           10101    S18_2795               26     167.06                1
# 10          10103    S10_1949               26     214.30               11
# 11          10103    S10_4962               42     119.67                4
# ...           ...         ...              ...        ...              ...
# 2988        10425    S18_3232               28     140.55                8
# 2989        10425    S18_4600               38     107.76               13
# 2991        10425    S24_2300               49     127.79                9
# 2994        10425    S32_2509               11      50.32                6
# 2995        10425    S50_1392               18      94.92                2
#
# [1103 rows x 5 columns]

# %%
df_orderdetails.columns
df_bool = df_orderdetails['quantityOrdered'] < 20
df_bool  # boolean values
result = df_orderdetails[df_bool]
result
# Out:
#       orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 2810        10401   S700_1691               11      77.64                8
# 2847        10407    S18_4409                6      91.11                3
# 2853        10407    S24_3191               13      77.05                7
# 2855        10408    S24_3969               15      41.03                1
# 2856        10409    S18_2325                6     104.25                2
# 2885        10412    S32_2509               19      50.86                7
# 2909        10415    S24_3420               18      59.83                2
# 2913        10416    S18_2581               15      70.96                4
# 2916        10416    S24_3949               18      64.83               13
# 2932        10418    S18_3278               16      70.76                2
# 2937        10418    S24_4620               10      66.29                3
# ...

# %%
df_orderdetails[df_orderdetails['quantityOrdered'] < 20]
# Out:
#       orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 2810        10401   S700_1691               11      77.64                8
# 2847        10407    S18_4409                6      91.11                3
# 2853        10407    S24_3191               13      77.05                7
# 2855        10408    S24_3969               15      41.03                1
# 2856        10409    S18_2325                6     104.25                2
# 2885        10412    S32_2509               19      50.86                7
# 2909        10415    S24_3420               18      59.83                2
# 2913        10416    S18_2581               15      70.96                4
# 2916        10416    S24_3949               18      64.83               13
# 2932        10418    S18_3278               16      70.76                2
# 2937        10418    S24_4620               10      66.29                3
# ...

# %%
# --------
# complete description of df
# --------

df_orderdetails.describe()
df_orderdetails.head()
df_orderdetails.tail()
df_orderdetails.columns
df_orderdetails.describe().T
df_orderdetails.index
df_orderdetails.shape
type(df_orderdetails)
df_orderdetails.isna().sum()  # display and count row with NaN value per column
df_orderdetails.isnull() # display false/true row without values
# Out:
#       orderNumber  productCode  quantityOrdered  priceEach  orderLineNumber
# 0           False        False            False      False            False
# 1           False        False            False      False            False
# 2           False        False            False      False            False
# 3           False        False            False      False            False
# 4           False        False            False      False            False
# ...           ...          ...              ...        ...              ...
# 2991        False        False            False      False            False
# 2992        False        False            False      False            False
# 2993        False        False            False      False            False
# 2994        False        False            False      False            False
# 2995        False        False            False      False            False
#
# [2996 rows x 5 columns]

# %%
df_customers_v2 = df_customers  # any change is reflected in both df

df_customers_v2['new'] = df_customers_v2['city']+df_customers_v2['country'] #add new column

df_customers_v2.drop('new', axis=1, inplace=True)

# drop column use axis=1 columns, axis=0 is row
#IMPORTANT:  inplace=True real delete the column from df

# %%
df_customers
# Out:
#                            customerNumber                    customerName  \
# customerNumber postalCode
# 103            44000                  103               Atelier graphique
# 112            83030                  112              Signal Gift Stores
# 114            3004                   114      Australian Collectors, Co.
# 119            44000                  119               La Rochelle Gifts
# 121            4110                   121              Baane Mini Imports
# ...                                   ...                             ...
# 486            71270                  486    Motor Mint Distributors Inc.
# 487            94217                  487        Signal Collectibles Ltd.
# 489            WA1 1DP                489  Double Decker Gift Stores, Ltd
# 495            51003                  495            Diecast Collectables
# 496            NaN                    496               Kelly's Gift Shop
#
# ...

# %%
df_customers_v2 = df_customers.copy(deep=True)  # any change in the copy NOT modify the original

df_customers_v2['new'] = df_customers_v2['city']+df_customers_v2['country'] #add new column

print(df_customers_v2.head().T)
print(df_customers.head().T)

#df_customers_v2.drop('new', axis=1, inplace=True)

# drop column use axis=1, axis=0 is row
#IMPORTANT:  inplace=True real delete the column from df
# Out:
#                                         0                   1  \
# customerNumber                        103                 112
# customerName            Atelier graphique  Signal Gift Stores
# contactLastName                   Schmitt                King
# contactFirstName                  Carine                 Jean
# phone                          40.32.2555          7025551838
# addressLine1               54, rue Royale     8489 Strong St.
# addressLine2                         None                None
# city                               Nantes           Las Vegas
# state                                None                  NV
# postalCode                          44000               83030
# country                            France                 USA
# salesRepEmployeeNumber               1370                1166
# creditLimit                         21000               71800
# new                          NantesFrance        Las VegasUSA
#
# ...

# %%
del df_customers_v2 # delete df - all object in Python

# %%
df_customers_v0
# --------
# recovery df feom original
# Important: create a copy of the original table (df)
# --------

df_customers = df_customers_v0.copy(deep=True)  # any change in the copy NOT MOODIFY the original

# .copy(deep=True)  NOT modify original

# %%
# ----------
# Index
# ----------


df_customers.head(3)
df_customers['new'] = df_customers['city']+df_customers['country'] #add new column

#df_customers.index
# set_index
# drop: default True, NOT Delete columns to be used as the new index.

# 1º- run with inplane=False to see result and not modify
#     df_customers.set_index(['customerNumber','postalCode'], drop=True, 
#     inplace=False)
# 2º- run with inplane=True to see result and modify permanent, 
# *Use drop=False only to NOT delete the columns that become index*

#df_customers.set_index(['customerNumber'], drop=True, inplace=True)
df_customers.set_index(['customerNumber','postalCode'], drop=True, inplace=True)

# %%
df_customers.reset_index() #use inplane=True to see result and modify permanent,
#df_customers.index
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %%
df_customers.index
# Out:
# MultiIndex([(103,   '44000'),
#             (112,   '83030'),
#             (114,    '3004'),
#             (119,   '44000'),
#             (121,    '4110'),
#             (124,   '97562'),
#             (125,  '01-012'),
#             (128,   '60528'),
#             (129,   '94217'),
#             (131,   '10022'),
#             ...
#             (475,   '94019'),
#             (477,   '68306'),
#             (480,  '196143'),
#             (481,   '47625'),
#             (484,   '41101'),
#             (486,   '71270'),
#             (487,   '94217'),
#             (489, 'WA1 1DP'),
#             (495,   '51003'),
#             (496,       nan)],
#            names=['customerNumber', 'postalCode'], length=122)

# %%
# Tips: to vreate a list for use as index

'CA NY WY OR CO'.split()  # USE METHOD SPLIT

# newIndex = 'CA NY WY OR CO'.split()  # USE METHOD SPLIT
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
newIndex = 'CA NY WY OR CO'.split()  # USE METHOD SPLIT

# %%
newIndex
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
# MultiLevel Index

# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3][1,2,3,1,2,3]
hier_index = list(zip(outside,inside))

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
hier_index2 = pd.MultiIndex(levels=[['G1','G2'],[1,2,3]], codes=[[0,0,0,1,1,1], 
              [0,1,2,0,1,2]])
hier_index2
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index2,columns=['A first','B second'])
df
# Out:
#        A first  B second
# G1 1  0.383704  0.450980
#    2  2.107901  0.319450
#    3  0.459026  0.113926
# G2 1  0.368812  1.553481
#    2  1.941110  0.183490
#    3 -2.425527  1.234634

# %%
df.loc['G1']
#df.iloc[0]
# Out:
#     A first  B second
# 1  0.383704  0.450980
# 2  2.107901  0.319450
# 3  0.459026  0.113926

# %%
df.loc['G1'].loc[1]
# Out:
# A first     0.383704
# B second    0.450980
# Name: 1, dtype: float64

# %%
df.index.names = ['Groups','Number']
df
# Out:
#                 A first  B second
# Groups Number
# G1     1       0.383704  0.450980
#        2       2.107901  0.319450
#        3       0.459026  0.113926
# G2     1       0.368812  1.553481
#        2       1.941110  0.183490
#        3      -2.425527  1.234634

# %%
df['A first']  # columns
# Out:
# Groups  Number
# G1      1         0.383704
#         2         2.107901
#         3         0.459026
# G2      1         0.368812
#         2         1.941110
#         3        -2.425527
# Name: A first, dtype: float64

# %%
df.loc['G1'] # row
# Out:
#          A first  B second
# Number
# 1       0.383704  0.450980
# 2       2.107901  0.319450
# 3       0.459026  0.113926

# %%
df.iloc[0]
# Out:
# A first     0.383704
# B second    0.450980
# Name: (G1, 1), dtype: float64

# %%
df.loc['G1'].loc[1]
# Out:
# A first     0.383704
# B second    0.450980
# Name: 1, dtype: float64
